# %%
options = {'debug'}
pinch = PyPinch('./streams/streams.csv', options)
pinch.shiftTemperatures()
pinch.constructTemperatureInterval()
pinch.constructProblemTable()
pinch.constructHeatCascade()
# Out:
# Streams:
# {'type': 'HOT', 'cp': 1.0, 'ts': 350.0, 'tt': 120.0, 'ss': 340.0, 'st': 110.0}
# {'type': 'HOT', 'cp': 3.0, 'ts': 260.0, 'tt': 150.0, 'ss': 250.0, 'st': 140.0}
# {'type': 'COLD', 'cp': 2.0, 'ts': 65.0, 'tt': 310.0, 'ss': 75.0, 'st': 320.0}
# {'type': 'COLD', 'cp': 0.5, 'ts': 100.0, 'tt': 170.0, 'ss': 110.0, 'st': 180.0}
# Tmin = 20.0
#
# Temperature Intervals:
# Interval 0 : {'t1': 340.0, 't2': 320.0, 'streamNumbers': [0]}
# Interval 1 : {'t1': 320.0, 't2': 250.0, 'streamNumbers': [0, 2]}
# Interval 2 : {'t1': 250.0, 't2': 180.0, 'streamNumbers': [0, 1, 2]}
# Interval 3 : {'t1': 180.0, 't2': 140.0, 'streamNumbers': [0, 1, 2, 3]}
# Interval 4 : {'t1': 140.0, 't2': 110.0, 'streamNumbers': [0, 2, 3]}
# Interval 5 : {'t1': 110.0, 't2': 75.0, 'streamNumbers': [2]}
#
# Problem Table:
# Interval 0 : {'deltaS': 20.0, 'deltaCP': 1.0, 'deltaH': 20.0}
# Interval 1 : {'deltaS': 70.0, 'deltaCP': -1.0, 'deltaH': -70.0}
# Interval 2 : {'deltaS': 70.0, 'deltaCP': 2.0, 'deltaH': 140.0}
# Interval 3 : {'deltaS': 40.0, 'deltaCP': 1.5, 'deltaH': 60.0}
# Interval 4 : {'deltaS': 30.0, 'deltaCP': -1.5, 'deltaH': -45.0}
# Interval 5 : {'deltaS': 35.0, 'deltaCP': -2.0, 'deltaH': -70.0}
#
# Unfeasible Heat Cascade:
# Interval 0 : {'deltaH': 20.0, 'exitH': 20.0}
# Interval 1 : {'deltaH': -70.0, 'exitH': -50.0}
# Interval 2 : {'deltaH': 140.0, 'exitH': 90.0}
# Interval 3 : {'deltaH': 60.0, 'exitH': 150.0}
# Interval 4 : {'deltaH': -45.0, 'exitH': 105.0}
# Interval 5 : {'deltaH': -70.0, 'exitH': 35.0}
#
# Feasible Heat Cascade:
# Interval 0 : {'deltaH': 20.0, 'exitH': 70.0}
# Interval 1 : {'deltaH': -70.0, 'exitH': 0.0}
# Interval 2 : {'deltaH': 140.0, 'exitH': 140.0}
# Interval 3 : {'deltaH': 60.0, 'exitH': 200.0}
# Interval 4 : {'deltaH': -45.0, 'exitH': 155.0}
# Interval 5 : {'deltaH': -70.0, 'exitH': 85.0}
#
# Pinch Temperature (degC): 250.0
# Minimum Hot Utility (kW): 50.0
# Minimum Cold Utility (kW): 85.0

# %%
options = {'draw'}
pinch = PyPinch('./streams/CaL.csv', options)
pinch.solve()
# pinch.shiftTemperatures()
# pinch.constructTemperatureInterval()
# pinch.constructProblemTable()
# pinch.constructHeatCascade()

# %%
options = {'draw'}
pinch = PyPinch('./streams/CaL1.csv', options)
pinch.solve()
# pinch.shiftTemperatures()
# pinch.constructTemperatureInterval()
# pinch.constructProblemTable()
# pinch.constructHeatCascade()
