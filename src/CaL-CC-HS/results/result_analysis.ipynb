# %%
import os
import sys
# CaLRepo = os.environ.get("CaLRepo")
CaLRepo ='/home/anoldfriend/Workspace/MyRepo/thermodynamics/CaL'
# print(CaLRepo)
sys.path.append(f"{CaLRepo}/utilities/")
from pyPinch import PyPinch
import numpy as np
import pandas as pd
import proplot as pplot
import matplotlib.pyplot as plt
import json
from result_plot import ResultPlot 

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
RP=ResultPlot()

# %% [markdown]
# ## 1. HTCW=1, HRCP=0, obj=energy

# %%
with open("./results_HTCW=1HRCP=0_energy.json","r") as fp:
    results10energy=json.load(fp)

# %%
fig,ax=RP.plotCompositeCurves(results10energy)
fig.savefig("./results_HTCW=1HRCP=0_energy/compositeDiagram.jpg", bbox_inches='tight')

# %%
fig, ax=RP.plotPowerPercentagePie(results10energy)
fig.savefig("./results_HTCW=1HRCP=0_energy/power_percentage.jpg", bbox_inches='tight')

# %%
fig,ax=RP.plotCostPercentagePie(results10energy)
fig.savefig("./results_HTCW=1HRCP=0_energy/price_percentage.jpg", bbox_inches='tight')

# %%
fig,axes=RP.plotPowerAndCostBars(results10energy)
fig.savefig("./results_HTCW=1HRCP=0_energy/power_costs.jpg", bbox_inches='tight')

# %% [markdown]
# ## HTCW=0,HRCP=1, obj=energy

# %%
with open("./results_HTCW=0HRCP=1_energy.json","r") as fp:
    results01energy=json.load(fp)

# %%
fig,ax=RP.plotCompositeCurves(results01energy)
fig.savefig("./results_HTCW=0HRCP=1_energy/compositeDiagram.jpg", bbox_inches='tight')

# %%
fig, ax=RP.plotPowerPercentagePie(results01energy)
fig.savefig("./results_HTCW=0HRCP=1_energy/power_percentage.jpg", bbox_inches='tight')

# %%
fig, ax=RP.plotCostPercentagePie(results01energy)
fig.savefig("./results_HTCW=0HRCP=1_energy/cost_percentage.jpg", bbox_inches='tight')

# %%
fig,axes=RP.plotPowerAndCostBars(results01energy)
fig.savefig("./results_HTCW=0HRCP=1_energy/power_costs.jpg", bbox_inches='tight')

# %% [markdown]
# ## HTCW=1,HRCP=1, obj=energy

# %%
with open("./results_HTCW=1HRCP=1_energy.json","r") as fp:
    results11energy=json.load(fp)

# %%
fig,ax=RP.plotCompositeCurves(results11energy)
fig.savefig("./results_HTCW=1HRCP=1_energy/compositeDiagram.jpg", bbox_inches='tight')

# %%
fig, ax=RP.plotPowerPercentagePie(results11energy)
fig.savefig("./results_HTCW=1HRCP=1_energy/power_percentage.jpg", bbox_inches='tight')

# %%
fig, ax=RP.plotCostPercentagePie(results11energy)
fig.savefig("./results_HTCW=1HRCP=1_energy/cost_percentage.jpg", bbox_inches='tight')

# %%
fig,axes=RP.plotPowerAndCostBars(results11energy)
fig.savefig("./results_HTCW=1HRCP=1_energy/power_costs.jpg", bbox_inches='tight')

# %% [markdown]
# ## HTCW=0, HRCP=1, obj=economic

# %%
with open("./results_HTCW=0HRCP=1_economic.json","r") as fp:
    results01economic=json.load(fp)

# %%
fig,ax=RP.plotCompositeCurves(results01economic)
fig.savefig("./results_HTCW=0HRCP=1_economic/compositeDiagram.jpg", bbox_inches='tight')

# %%
fig, ax=RP.plotPowerPercentagePie(results01economic)
fig.savefig("./results_HTCW=0HRCP=1_economic/power_percentage.jpg", bbox_inches='tight')

# %%
fig, ax=RP.plotCostPercentagePie(results01economic)
fig.savefig("./results_HTCW=0HRCP=1_economic/cost_percentage.jpg", bbox_inches='tight')

# %%
fig, ax=RP.plotPowerAndCostBars(results01economic)
fig.savefig("./results_HTCW=0HRCP=1_economic/power_costs.jpg", bbox_inches='tight')
