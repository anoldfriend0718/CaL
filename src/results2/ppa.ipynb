# %%
import sys
import pandas as pd 
import numpy as np
sys.path.append("/home/anoldfriend/Workspace/MyRepo/thermodynamics/CaL/src/CaL-CC-HS")
from pyCaLPlant import Pinch_point_analyzer
CaLRepo = '/home/anoldfriend/Workspace/MyRepo/thermodynamics/CaL'
# print(CaLRepo)
sys.path.append(f"{CaLRepo}/utilities/")
from pyPinch import PyPinch
import json
# %load_ext autoreload
# %autoreload 2

# %%
pa_text="Tmin 15 \n        CP    TSUPPLY    TTARGET\n  3.675554 650.000000  20.000000\n  4.525504 650.000000  40.000000\n  5.250345  58.064117  60.000001\n  2.385097  20.000000 359.198757\n160.080011  60.000000  85.000000"
pinch = PyPinch(pa_text)
options = {'debug','draw'}
pinch.solve(options)
# Out:
# Streams:
# {'type': 'HOT', 'cp': 3.675554, 'ts': 650.0, 'tt': 20.0, 'ss': 642.5, 'st': 12.5}
# {'type': 'HOT', 'cp': 4.525504, 'ts': 650.0, 'tt': 40.0, 'ss': 642.5, 'st': 32.5}
# {'type': 'COLD', 'cp': 5.250345, 'ts': 58.064117, 'tt': 60.000001, 'ss': 65.56411700000001, 'st': 67.500001}
# {'type': 'COLD', 'cp': 2.385097, 'ts': 20.0, 'tt': 359.198757, 'ss': 27.5, 'st': 366.698757}
# {'type': 'COLD', 'cp': 160.080011, 'ts': 60.0, 'tt': 85.0, 'ss': 67.5, 'st': 92.5}
# Tmin = 15.0
#
# Temperature Intervals:
# Interval 0 : {'t1': 642.5, 't2': 366.698757, 'streamNumbers': [0, 1]}
# Interval 1 : {'t1': 366.698757, 't2': 92.5, 'streamNumbers': [0, 1, 3]}
# Interval 2 : {'t1': 92.5, 't2': 67.500001, 'streamNumbers': [0, 1, 3, 4]}
# Interval 3 : {'t1': 67.500001, 't2': 67.5, 'streamNumbers': [0, 1, 2, 3, 4]}
# Interval 4 : {'t1': 67.5, 't2': 65.56411700000001, 'streamNumbers': [0, 1, 2, 3]}
# Interval 5 : {'t1': 65.56411700000001, 't2': 32.5, 'streamNumbers': [0, 1, 3]}
# Interval 6 : {'t1': 32.5, 't2': 27.5, 'streamNumbers': [0, 3]}
# Interval 7 : {'t1': 27.5, 't2': 12.5, 'streamNumbers': [0]}
#
# Problem Table:
# Interval 0 : {'deltaS': 275.801243, 'deltaCP': 8.201058, 'deltaH': 2261.861990315094}
# Interval 1 : {'deltaS': 274.198757, 'deltaCP': 5.815961, 'deltaH': 1594.729276960477}
# Interval 2 : {'deltaS': 24.999999000000003, 'deltaCP': -154.26405000000003, 'deltaH': -3856.601095735951}
# Interval 3 : {'deltaS': 9.999999974752427e-07, 'deltaCP': -159.514395, 'deltaH': -0.0001595143945972649}
# Interval 4 : {'deltaS': 1.9358829999999898, 'deltaCP': 0.5656159999999995, 'deltaH': 1.0949663989279932}
# Interval 5 : {'deltaS': 33.06411700000001, 'deltaCP': 5.815961, 'deltaH': 192.29961497143705}
# Interval 6 : {'deltaS': 5.0, 'deltaCP': 1.290457, 'deltaH': 6.452285}
# Interval 7 : {'deltaS': 15.0, 'deltaCP': 3.675554, 'deltaH': 55.13331}
#
# Unfeasible Heat Cascade:
# Interval 0 : {'deltaH': 2261.861990315094, 'exitH': 2261.861990315094}
# Interval 1 : {'deltaH': 1594.729276960477, 'exitH': 3856.5912672755708}
# Interval 2 : {'deltaH': -3856.601095735951, 'exitH': -0.009828460380049364}
# Interval 3 : {'deltaH': -0.0001595143945972649, 'exitH': -0.009987974774646628}
# Interval 4 : {'deltaH': 1.0949663989279932, 'exitH': 1.0849784241533467}
# Interval 5 : {'deltaH': 192.29961497143705, 'exitH': 193.3845933955904}
# Interval 6 : {'deltaH': 6.452285, 'exitH': 199.8368783955904}
# Interval 7 : {'deltaH': 55.13331, 'exitH': 254.97018839559038}
#
# Feasible Heat Cascade:
# Interval 0 : {'deltaH': 2261.861990315094, 'exitH': 2261.8719782898684}
# Interval 1 : {'deltaH': 1594.729276960477, 'exitH': 3856.6012552503453}
# Interval 2 : {'deltaH': -3856.601095735951, 'exitH': 0.00015951439445416327}
# Interval 3 : {'deltaH': -0.0001595143945972649, 'exitH': -1.4310162213190813e-13}
# Interval 4 : {'deltaH': 1.0949663989279932, 'exitH': 1.0949663989278502}
# Interval 5 : {'deltaH': 192.29961497143705, 'exitH': 193.3945813703649}
# Interval 6 : {'deltaH': 6.452285, 'exitH': 199.8468663703649}
# Interval 7 : {'deltaH': 55.13331, 'exitH': 254.9801763703649}
#
# Pinch Temperature (degC): 67.5
# Minimum Hot Utility (kW): 0.009987974774646628
# Minimum Cold Utility (kW): 254.9801763703649
#
# Shifted Composite Diagram Values:
# DeltaH Hot: [55.13331, 18.377769999999998, 271.1607412357861, 15.876288764213916, 8.201057979294319e-06, 205.02644179894202, 2248.719909684906, 2261.861990315094]
# DeltaH Cold: [0.0, 11.925485, 78.86112626434902, 14.781322365285924, 0.0001677154525765592, 4061.627537534893, 653.990632724429, 0.0]
#
# Hot H: [0.0, 55.13331, 73.51107999999999, 344.67182123578607, 360.54811, 360.548118201058, 565.57456, 2814.294469684906, 5076.15646]
# Hot T: [12.5, 27.5, 32.5, 65.56411700000001, 67.5, 67.500001, 92.5, 366.698757, 642.5]
#
# Cold H: [254.9801763703649, 266.9056613703649, 345.7667876347139, 360.54810999999984, 360.5482777154524, 4422.175815250345, 5076.166447974774]
# Cold T: [27.5, 32.5, 65.56411700000001, 67.5, 67.500001, 92.5, 366.698757]
#
# Grand Composite Curve:
# Net H (kW): [0.009987974774646628, 2261.8719782898684, 3856.6012552503453, 0.00015951439445416327, -1.4310162213190813e-13, 1.0949663989278502, 193.3945813703649, 199.8468663703649, 254.9801763703649]
# T (degC): [642.5, 366.698757, 92.5, 67.500001, 67.5, 65.56411700000001, 32.5, 27.5, 12.5]
